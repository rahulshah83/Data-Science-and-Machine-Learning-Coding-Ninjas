# %%
# Laptop Sales
# Given data of distribution of sales of different laptops in year 2018 in india (Company name number of laptops sold). 
# plot a pie graph and show the %age distribution. Print the value of %age distribution also.

# Note: Print the %age upto 1 decimal place and in same order as given in data. Don't print the %sign, just print the number upto 1 decimal place.

# output Format:
# company_name1 percentage1
# company_name1 percentage1
# ...
# ...
# ...

# %%
import matplotlib.pyplot as plt
import math

company=['HP','Dell','Lenovo','Asus','Apple','Acer']
sold=[20000,43000,15000,17000,22000,13000]
colors = ["blue","red","orange","grey","pink","green"]

sum = sum(sold)

values=[]
for s in sold:
    values.append((s/sum)*100)


plt.pie(sold, colors=colors, labels= company, autopct="%.1f%%")

plt.show()

for i in range(0,len(sold)):
    print(company[i], "{0:.1f}".format( values[i]))
# Out:
# HP 15.4
# Dell 33.1
# Lenovo 11.5
# Asus 13.1
# Apple 16.9
# Acer 10.0

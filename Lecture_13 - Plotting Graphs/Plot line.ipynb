# %%
# Plot line
# Given tow integer arrays, X and Y. Plot the graph between X and Y
# From the help of graph, determine the range of Y when the valueof X is 8

# plot and print the range of Y

# Note: Here lower limit and upper limit of rnag must be multiple of 10 and difference betweenupper limit and lower limit must be equal to 10.
    
# Output Format
# lower_limit to upper_limit

# %%
import matplotlib.pyplot as plt
x = [0,1,2,3,4,5,6,7,9,10]
y = [1,2,5,10,17,26,37,50,82,101]
plt.plot(x,y)
plt.grid()
plt.show()
print(60,"to",70)
# Out:
# 60 to 70
